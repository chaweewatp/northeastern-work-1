# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams.update({'font.size': 22})
plt.rcParams["font.family"] = "Times New Roman"

import matplotlib.gridspec as gridspec

# %%
def find_LF(list_kW):
    kW=np.array(list_kW)
    return kW.mean()/kW.max()

def plot_kWhr(dict_AMR, AMR_id):
    fig, ax = plt.subplots()
    ax1 = plt.subplot2grid((1,5), (0,0), colspan=1, rowspan=1)
    ax1.boxplot(y)

# %%
dict_AMR_MC=np.load('dict_MC_AMR.npy')[()]

# %%
print(dict_AMR_MC.keys())
# Out:
# dict_keys([21652, 136898, 137091, 137138, 42432, 66543, 21654, 42421, 42423, 43958, 137110, 42422, 21655, 42431, 44834, 56452, 56457, 56458, 124642, 124647, 124649, 124656, 124683, 185767, 56448, 136900, 137094, 164978, 189318, 193781, 44318, 124687, 21689, 44831, 56459, 124678])

# %%
AMR_id=185767
num_sample=20
for AMR_id in list(dict_AMR_MC.keys()):
    fig, ax = plt.subplots()
    for sample in np.arange(0,num_sample,1):
        x=list(dict_AMR_MC[AMR_id].keys())
        y=[dict_AMR_MC[AMR_id][x][sample] for x in dict_AMR_MC[AMR_id]]
        ax.plot(x,y, 'ko', label='{}'.format(find_LF(y)))
    # plt.legend()
    plt.show()
# Out:
# /Users/pornchaichaweewat/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig = plt.figure(1)
# Plot figure with subplots of different sizes
fig = plt.figure(1)
# set up subplot grid
gridspec.GridSpec(1,5)

ax1 = plt.subplot2grid((1,5), (0,0), colspan=1, rowspan=1)
data=[x for x in list(df_AMR_data['LF_SUB']) if x is not "None"]
ax1.boxplot(data)
ax1.set_ylim(0,1)
ax1.set_xticklabels(['NIA'])
ax1.set_xlabel('Substation')
ax1.set_ylabel('Load factor')

ax2 = plt.subplot2grid((1,5), (0,1), colspan=5, rowspan=1)
data=[[x for x in list(df_AMR_data['LF_OUT{}'.format(feeder)]) if x is not "None"] for feeder in ['01','02','03','04','05', '06','08','09','10']]
ax2.boxplot(data)
ax2.set_ylim(0,1)
ax2.set_xticklabels(['1','2','3','4','5','6','8','9','10'])
ax2.set_xlabel('Feeder')
plt.show()
fig_name = 'plot_LF_SUB_NIA.png'

fig.savefig(fig_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9f81c79654d1> in <module>()
#       6
#       7 ax1 = plt.subplot2grid((1,5), (0,0), colspan=1, rowspan=1)
# ----> 8 data=[x for x in list(df_AMR_data['LF_SUB']) if x is not "None"]
#       9 ax1.boxplot(data)
#      10 ax1.set_ylim(0,1)
#
# NameError: name 'df_AMR_data' is not defined

# %%
gridspec.GridSpec(1,5)
def plot_kWhr(dict_AMR, AMR_id):
    num_sample=20
    LF_data=[]
    fig = plt.figure(1)
    ax1 = plt.subplot2grid((1,5), (0,0), colspan=5, rowspan=1)

    for sample in np.arange(0,num_sample,1):
        x=list(dict_AMR_MC[AMR_id].keys())
        y=[dict_AMR_MC[AMR_id][x][sample] for x in dict_AMR_MC[AMR_id]]
        LF_data.append(find_LF(y))
        ax1.plot(x,y)
        
    ax2 = plt.subplot2grid((1,5), (0,1), colspan=1, rowspan=1)
    ax2.boxplot(LF_data)
    ax2.set_xticklabels(['{}'.format(AMR_id)])
    ax2.set_xlabel('AMR id')
    ax2.set_ylabel('Load factor')
    plt.show()

#     return LF_data

# %%
plot_kWhr(dict_AMR_MC, 42421)
