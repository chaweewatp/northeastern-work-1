# %%
import numpy as np

# %%
dict_1=np.load('AMR_dict.npy')[()]

# %%
dict_1.keys()
# Out:
# dict_keys([21652, 136898, 137091, 137138, 42432, 66543, 21654, 42421, 42423, 43958, 137110, 42422, 21655, 42431, 44834, 56452, 56457, 56458, 124642, 124647, 124649, 124656, 124683, 185767, 56448, 136900, 137094, 164978, 189318, 193781, 44318, 124687, 21689, 44831, 56459, 124678])

# %%
dict_1[21652].keys()
# Out:
# dict_keys(['working_day', 'non_working_day'])

# %%
dict_1[21652]['working_day'].keys()
# Out:
# dict_keys(['mean', 'max', 'LF', 'cost', 'other'])

# %%
dict_1[21652]['working_day']['LF']
# Out:
# array([0.44301905, 0.45240861, 0.38520916, 0.44105619, 0.48319236,
#        0.46450152, 0.47649094, 0.44413654, 0.28807218, 0.40931026,
#        0.48635754, 0.48981399, 0.50576715, 0.46706376, 0.43756476,
#        0.12608671, 0.46212643, 0.47254879, 0.17531626, 0.32526433,
#        0.45656042, 0.47740254, 0.45246224, 0.47737218, 0.44160507,
#        0.44916693, 0.4001004 , 0.51376076, 0.57705169, 0.47301809,
#        0.46421358, 0.47577056, 0.4821671 , 0.51094764, 0.47279923,
#        0.49472194, 0.55530902, 0.4255817 , 0.5346953 , 0.50560545,
#        0.50837595, 0.51720902, 0.5502625 , 0.50093442, 0.50097162,
#        0.51320166, 0.4858287 , 0.46053189, 0.52383566, 0.52640891,
#        0.56535603, 0.47029176, 0.49978233, 0.4915682 , 0.49065247,
#        0.36997589, 0.50619601, 0.44015195, 0.4781268 , 0.48851871,
#        0.55507401, 0.50496882, 0.43559209, 0.50142104, 0.42459703,
#        0.51788408, 0.43095181, 0.50798285, 0.46653112, 0.50078422,
# ...

# %%
dict_1[21652]['working_day']['cost']
# Out:
# array([ 70914.48003489,  73330.6503329 ,  62616.21875264,  76306.99123306,
#         80762.46582294,  77248.90085645,  75458.55939414,  72292.93542328,
#           226.24655793,  71206.26937945,  84442.06956244,  79027.09078977,
#         77891.37855596,  75536.86451144,  74876.70264334,  19926.51198993,
#         75977.96269242,  75134.45984487,  33662.81671224,  54856.62093933,
#         78775.95018005,  77276.66055502,  76027.041299  ,  78479.4117493 ,
#         73230.32169134,  76891.69853282,  64586.70683206,  82587.63763801,
#         94473.84362595,  79883.84826581,  76659.38106863,  81601.96415565,
#         81988.84671032,  83531.42529591,  78264.24533186,  80397.20195149,
#         87276.62864838,  69913.77485551,  86927.13637355,  82691.93515556,
#         82288.7070806 ,  83209.95746079,  92818.0033781 ,  85712.29473643,
#         82091.17998582,  83593.4792014 ,  78231.68163057,  79146.62573648,
# ...

# %%
print('AMR ID', 'cost_ mean', 'cost_STD')
for key1 in list(dict_1.keys()):
    print(key1, '&', dict_1[key1]['working_day']['cost'].mean(), '&' ,dict_1[key1]['working_day']['cost'].std())

    
print('AMR ID', 'LF_ mean', 'LF_STD')
for key1 in list(dict_1.keys()):
    print(key1, '&', dict_1[key1]['working_day']['LF'].mean(), '&',dict_1[key1]['working_day']['LF'].std())
# Out:
# AMR ID cost_ mean cost_STD
# 21652 & 75138.99424131015 & 14264.348282355666
# 136898 & 153630.04798937417 & 23736.39868244368
# 137091 & 34052.69739313608 & 9608.483934623504
# 137138 & 33384.41934556301 & 16727.58028065167
# 42432 & 236815.97531960177 & 44446.493733825955
# 66543 & 12455.61206276424 & 2569.2770469069324
# 21654 & 6795.165211733408 & 6970.344703289428
# 42421 & 67473.44451432406 & 11738.401616814634
# 42423 & 5743.137173701693 & 3469.867129805136
# 43958 & 70504.07394669627 & 16974.94252571955
# 137110 & 11973.42185554925 & 2165.8117925368406
# 42422 & 0.0 & 0.0
# 21655 & 5579.1831335647785 & 1591.130937939091
# 42431 & 12356.892095697904 & 3402.0124008605303
# 44834 & 63664.70087670426 & 11412.196121753068
# 56452 & 213943.30265769147 & 35413.105747267626
# 56457 & 36414.995315447544 & 4492.033890986469
# 56458 & 28127.747003928987 & 3577.102869534707
# 124642 & 65564.4209827337 & 9881.203898081205
# 124647 & 56147.73949878086 & 8723.498374087818
# ...
